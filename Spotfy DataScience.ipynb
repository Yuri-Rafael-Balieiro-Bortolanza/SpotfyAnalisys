# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
low_memory=False

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
filename = 'featuresdf.csv'

# %%
df = pd.read_csv(filename)

# %%
df.sample(10)
# Out:
#                        id                             name         artists  \
# 12  0dA2Mk56wEzDgegdC6R17         Stay (with Alessia Cara)            Zedd
# 42  5bcTCxgc7xVfSaMV3RuVk                            Feels   Calvin Harris
# 81  3AEZUABDXNtecAOSC1qTf       Reggaetón Lento (Bailemos)            CNCO
# 0   7qiZfU4dY1lWllzX7mPBI                     Shape of You      Ed Sheeran
# 61  3umS4y3uQDkqekNjVpiRU                        El Amante       Nicky Jam
# 37  7wGoVu4Dady5GV0Sv4UIs                         rockstar     Post Malone
# 5   7KXjTSCq5nL1LoYtL7XAw                          HUMBLE.  Kendrick Lamar
# 64  1louJpMmzEicAn7lzDalP  No Promises (feat. Demi Lovato)     Cheat Codes
# 10  7GX5flRQZVHRAGd6B4TmD                    XO TOUR Llif3    Lil Uzi Vert
# 66  5hYTyyh2odQKphUbMqc5g   How Far I'll Go - From "Moana"    Alessia Cara
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# ...

# %%
df.groupby('duration_ms').size().sort_values().plot(kind='hist', figsize=(10,25))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-368cc668246c> in <module>()
# ----> 1 help(figsize)
#
# NameError: name 'figsize' is not defined
